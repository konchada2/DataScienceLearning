# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/SANTOSHSRINIVAS/Desktop/Data_Science_Learning/titanic_train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df_female = df['Sex'] == 'female'

# %%
df_female[0:10]
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: Sex, dtype: bool

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
len(df)
# Out:
# 891

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'] = df['Embarked'].fillna("S")

# %%
df['Embarked'].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df[['Survived','Embarked']][:10]
# Out:
#    Survived Embarked
# 0         0        S
# 1         1        C
# 2         1        S
# 3         1        S
# 4         0        S
# 5         0        Q
# 6         0        S
# 7         0        S
# 8         1        S
# 9         1        C

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
less_50_df = df[df['Age'] < 50]

# %%
less_50_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
len(less_50_df)
# Out:
# 640

# %%
len(df)
# Out:
# 891

# %% [markdown]
# # Filterng data using pandas

# %%
df[(df['Age'] > 20) & (df['Age'] < 50) & (df['Embarked'] =='S')]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 8              9         1       3
# 13            14         0       3
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 23            24         1       1
# 25            26         1       3
# 35            36         0       1
# 37            38         0       3
# 40            41         0       3
# 41            42         0       2
# 51            52         0       3
# 53            54         1       2
# 56            57         1       2
# 61            62         1       1
# 62            63         0       1
# 66            67         1       2
# 69            70         0       3
# 70            71         0       2
# 72            73         0       2
# 74            75         1       3
# ...

# %%
df[(df['Age'] > 50 ) & (df['Survived'] == 1) & (df["Sex"]=='male')] # Males aged above 50 who have survived
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 449          450         1       1        Peuchen, Major. Arthur Godfrey
# 570          571         1       2                    Harris, Mr. George
# 587          588         1       1      Frolicher-Stehli, Mr. Maxmillian
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 647          648         1       1   Simonius-Blumer, Col. Oberst Alfons
# 857          858         1       1                Daly, Mr. Peter Denis
#
#       Sex   Age  SibSp  Parch       Ticket   Fare Cabin Embarked
# 449  male  52.0      0      0       113786  30.50  C104        S
# 570  male  62.0      0      0  S.W./PP 752  10.50   NaN        S
# 587  male  60.0      1      1        13567  79.20   B41        C
# 630  male  80.0      0      0        27042  30.00   A23        S
# 647  male  56.0      0      0        13213  35.50   A26        C
# 857  male  51.0      0      0       113055  26.55   E17        S

# %% [markdown]
# # Na Values in a Dataframe

# %%
df.isnull().values.any()
# Out:
# True

# %%
df['Age'].isnull().value_counts()
# Out:
# False    714
# True     177
# Name: Age, dtype: int64

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Age'].isnull().value_counts()
# Out:
# False    891
# Name: Age, dtype: int64

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['Cabin']

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6', 'C23 C25 C27',
#        'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33', 'F G73', 'E31',
#        'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101', 'F E69', 'D47',
#        'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4', 'A32', 'B4',
#        'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35', 'C87', 'B77',
#        'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19', 'B49', 'D',
#        'C22 C26', 'C106', 'C65', 'E36', 'C54', 'B57 B59 B63 B66', 'C7',
#        'E34', 'C32', 'B18', 'C124', 'C91', 'E40', 'T', 'C128', 'D37',
#        'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44', 'A34', 'C104', 'C111',
#        'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37', 'C30', 'D20',
#        'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39', 'B22', 'C86',
#        'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41', 'A20', 'D19',
#        'D50', 'D9', 'A23', 'B50', 'A26', 'D48', 'E58', 'C126', 'B71',
# ...

# %% [markdown]
# # Length of a dataframe

# %%
len(df['Cabin'].unique())
# Out:
# 148

# %%
df1 = df.dropna(how='any')

# %%
len(df['Cabin'].unique())
# Out:
# 148

# %% [markdown]
# # Subsetting Data using Criteria

# %%
df3=df[(df["Pclass"] == 3) & (df["Sex"]=="male")]

# %%
df3[:10]
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex  \
# 0             1         0       3         Braund, Mr. Owen Harris  male
# 4             5         0       3        Allen, Mr. William Henry  male
# 5             6         0       3                Moran, Mr. James  male
# 7             8         0       3  Palsson, Master. Gosta Leonard  male
# 12           13         0       3  Saundercock, Mr. William Henry  male
# 13           14         0       3     Andersson, Mr. Anders Johan  male
# 16           17         0       3            Rice, Master. Eugene  male
# 26           27         0       3         Emir, Mr. Farred Chehab  male
# 29           30         0       3             Todoroff, Mr. Lalio  male
# 36           37         1       3                Mamee, Mr. Hanna  male
#
#           Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0   22.000000      1      0  A/5 21171   7.2500   NaN        S
# ...

# %% [markdown]
# # Selecting columns using Pandas

# %%
df[["Name","Sex","Age","Survived","Cabin","Embarked"]][0:10]
# Out:
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# 7                     Palsson, Master. Gosta Leonard    male   2.000000
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
#
#    Survived Cabin Embarked
# 0         0   NaN        S
# 1         1   C85        C
# 2         1   NaN        S
# 3         1  C123        S
# 4         0   NaN        S
# ...

# %% [markdown]
# # Count of distinct elements in a column

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# # Check to see if a value exists in a column or not

# %%
Pclass_3=df["Pclass"]== 3
Pclass_3.head(8)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# 7     True
# Name: Pclass, dtype: bool

# %%
#Females who have survived
female = df["Sex"]=="female"
survived = df["Survived"]== 1
df[female & survived][['PassengerId','Pclass','Name','Embarked']][:10]
# Out:
#     PassengerId  Pclass                                               Name  \
# 1             2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2             3       3                             Heikkinen, Miss. Laina
# 3             4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8             9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9            10       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10           11       3                    Sandstrom, Miss. Marguerite Rut
# 11           12       1                           Bonnell, Miss. Elizabeth
# 15           16       2                   Hewlett, Mrs. (Mary D Kingcome)
# 19           20       3                            Masselmani, Mrs. Fatima
# 22           23       3                        McGowan, Miss. Anna "Annie"
#
#    Embarked
# 1         C
# 2         S
# 3         S
# 8         S
# 9         C
# 10        S
# 11        S
# 15        S
# 19        C
# ...

# %% [markdown]
# # Distinct values in a column

# %%
df.Pclass.unique()         # or df["Pclass"].unique
# Out:
# array([3, 1, 2], dtype=int64)
